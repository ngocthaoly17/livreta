# %%
## projet 2

"""Fondamentaux Python

Projets

Combien vous rapporte votre livret A ?
Il parait que si Christophe Colomb avait mis 1€ de côté qu’il avait laissé à 2% d’intérêt par an,
aujourd’hui ses héritiers n’auraient plus besoin de travailler pour vivre leur vie. Essayons de
calculer la même chose pour notre livret A.
1) Créons donc une fonction qui va nous permettre de savoir combien d’argent un
utilisateur aura au total au bout d’un certain nombre d’années
2) L’utilisateur devra pouvoir appeler la fonction qui ensuite lui demandera :
a) La somme totale qu’il souhaite placer
b) Le nombre d’années pendant lesquelles il souhaite placer son argent
c) Le taux d’intérêt auquel il a droit
3) Faite attention aux erreurs que peut rentrer l’utilisateur
a) S’il entre une chaîne de caractères plutôt qu’un nombre, une erreur devra
ressortir
b) Si l’utilisateur met des chiffres négatifs, une erreur devra, de même, sortir
c) Enfin, il est très probable que l’utilisateur écrive le taux d’intérêt en pourcentage
(ex: 10%). Levez une erreur si tel est le cas pour le prévenir de mettre un
nombre décimal

4) Pour terminer, le programme devra ressortir qu’un chiffre avec au maximum deux
chiffres après la virgule.
INDICE : La formule pour calculer un taux d’intérêt est :

TO-DO LIST
Pratiquons un peu les collections de données en créant une to-do list. Une fois le programme
lancé il devra :
1) Montrer la To-do list en cours
2) Demander si l’utilisateur veut ajouter une to-do
3) Demander si l’utilisateur veut enlever une to-do
4) Enlever ou ajouter la to-do correspondante"""


def interet(k,t,nb):
    try:
        x = k*(1 + (t/100))** nb
        return x
    
    except:
        print("veuillez mettre qu'une valeur numérique")
         
        
to_do = []

def show_todo():
    if to_do == []:
        print("vous n'avez rien a faire")
    else:
        print("voici votre to do list")
        for item in to_do:
            print(item)
                
def ajouter():
    
    new_todo = input("que voulez vous ajouter?")
    to_do.append(new_todo)
    
    return to_do

def remove_item():
    remove_item = input("qu'est ce que vous avez fait?")
    to_do_remove(remove_item)

    return to_do

# %%
###exercice 2

"""Les listes
1) Voici une liste [“Bonjour”, “Je”, “Michel”, “m’appelle”]
a) Stocker cette liste dans une variable qu’on appellera michel
b) Faites une boucle pour que la console retourne chacun des items de la liste
c) On a un problème avec cette phrase, deux mots sont inversés. Trouvez un
moyen d’inverser le dernier item avec l’avant dernier


2) Voici une liste d’âge : [12, 16, 34, 58, 9].
a) Stockez cette liste d’âge dans une variable qu’on appellera age
b) On aimerait que cette liste soit rangée par ordre croissant, comment faire ?


Les dictionnaires
1) Nous vous avions dit que les dictionnaires étaient très utiles avec les API, et bien
justement tentons d’utiliser l’API de Star Wars.
a) Dans votre éditeur de texte, écrivez :


b) Ceci va permettre d’appeler l’API de Star Wars de la stocker sur un format
dictionnaire dans une variable qu’on a appelé dic.
c) Regardez ce que contient le dictionnaire via une boucle
d) On aimerait faire une jolie phrase qui permette de décrire le personnage comme
ceci : “{{nom}} mesure {{taille}} cm et pèse {{poids}} kg. Il est est né en
{{naissance}}”
e) Importez un nouveau personnage en changeant"""


liste = ["bonjour", "je", "michel", "m'appelle"]
premier_element = liste.pop(2)
premier_element
liste.append(premier_element)
liste



import requests
request = requests.get("https://swapi.co/api/people/1/")
dic = r.json()
